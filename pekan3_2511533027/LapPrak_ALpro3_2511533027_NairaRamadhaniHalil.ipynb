# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“OPERATOR PYTHON”**
#
# **Disusun Oleh :**
#
# **Naira Ramadhani Halil**
#
# **2511533027**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/Logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan Pemograman yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pembahasan Operator Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep pemahaman mengenai operator pemograman menggunakan bahasa Python.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pemrograman Python, operator merupakan bagian penting yang digunakan untuk mengolah data dan menjalankan berbagai proses dalam program. Operator dapat digunakan untuk melakukan perhitungan, membandingkan nilai, menggabungkan kondisi, serta memeriksa hubungan antara data.
#
# Pada praktikum Algoritma Pemrograman Pekan 3, dipelajari beberapa jenis operator Python, yaitu operator aritmatika, assignment, bitwise, keanggotaan, identitas, logika, dan perbandingan. Setiap operator memiliki fungsi yang berbeda, seperti melakukan perhitungan, memberikan atau mengubah nilai variabel, mengolah bilangan biner, memeriksa keanggotaan data, membandingkan identitas objek, serta menentukan kondisi True atau False. Melalui praktikum ini, penggunaan operator tersebut diterapkan dalam beberapa program sederhana agar dapat memahami fungsi dan cara penggunaannya.
#
# ## 1.2 Tujuan
# Tujuan praktikum sebagai berikut:
# 1. Mengetahui dan memahami penggunaan berbagai jenis operator pada bahasa pemrograman Python, seperti operator aritmatika, assignment, bitwise, keanggotaan, identitas, logika, dan perbandingan.
# 2. Mampu menerapkan berbagai operator Python ke dalam program berdasarkan fungsi dan kebutuhan masing-masing.
# 3. Mampu memahami hasil operasi dan menggunakan nilai True atau False sebagai dasar dalam pengolahan kondisi pada program.
#
# ## 1.3 Manfaat
# Manfaat praktikum sebagai berikut:
# 1. Menambah pemahaman mengenai fungsi dan cara penggunaan berbagai operator dalam bahasa pemrograman Python.
# 2. Melatih kemampuan dalam membuat program sederhana yang menggunakan operasi perhitungan, perbandingan, logika, serta pengolahan data.
# 3. Membantu memahami konsep dasar operator yang dapat digunakan sebagai dasar dalam pembuatan program Python yang lebih kompleks.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Python merupakan bahasa pemrograman yang memiliki berbagai jenis operator untuk melakukan operasi terhadap data. Operator digunakan untuk membantu program dalam melakukan perhitungan, perbandingan, pengolahan kondisi, maupun manipulasi data. Hasil dari penggunaan operator dapat berupa nilai numerik, Boolean (True atau False), maupun data lainnya.
#
# Beberapa operator yang dipelajari pada praktikum ini yaitu:
#
# 1. Operator Aritmatika
# Digunakan untuk melakukan operasi matematika, seperti penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), sisa bagi (%), dan perpangkatan (**).
# 2. Operator Assignment
# Digunakan untuk memberikan nilai pada variabel. Selain assignment biasa (=), terdapat augmented assignment seperti +=, -=, *=, /=, //=, %=, dan **= yang digunakan untuk memperbarui nilai variabel.
# 3. Operator Bitwise
# Digunakan untuk melakukan operasi pada bilangan dalam bentuk biner. Operator yang digunakan antara lain AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>).
# 4. Operator Keanggotaan (Membership)
# Digunakan untuk memeriksa apakah suatu nilai terdapat di dalam suatu data. Operator yang digunakan adalah in dan not in.
# 5. Operator Identitas (Identity)
# Digunakan untuk membandingkan identitas dua objek. Operator is digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama, sedangkan is not digunakan untuk memeriksa apakah keduanya merupakan objek yang berbeda.
# 6. Operator Logika
# Digunakan untuk menggabungkan atau membalik kondisi Boolean. Operator yang digunakan adalah and, or, dan not.
# 7. Operator Perbandingan
# Digunakan untuk membandingkan dua nilai dan menghasilkan nilai Boolean berupa True atau False. Operatornya meliputi >, <, >=, <=, ==, dan !=.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2511533027"

# %%
angka1_3027 = int(input("Input angka-1: "))
angka2_3027 = int(input("Input angka-2: "))

#Penjumlahan
hasil = angka1_3027 + angka2_3027
print("\nOperator Penjumlahan")
print("Hasil: ", hasil)

#Pengurangan
hasil = angka1_3027 - angka2_3027
print("\nOperator Pengurangan")
print("Hasil: ", hasil)

#Perkalian
hasil = angka1_3027 * angka2_3027
print("\nOperator Perkalian")
print("Hasil =", hasil)

#Pembagian, pembagian bulat, dan sisa bagi
if angka1_3027 !=0:
    hasil = angka1_3027 / angka2_3027
    print("\nOperator Pembagian")
    print("Hasil =", hasil)
    
    hasil = angka1_3027 // angka2_3027
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil)
    
    hasil = angka1_3027 % angka2_3027
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil)
    
else:
    print("Angka kedua tidak boleh bernilai 0.")
    
#Pangkat
hasil = angka1_3027 ** angka2_3027
print("\nOperator Pangkat")
print("Hasil =", hasil)

# %% [markdown]
# **Penjelasan :**
# Kode pertama digunakan untuk menerapkan berbagai operator aritmatika pada Python.
#
# 1. Program meminta pengguna memasukkan dua angka dan mengubah input tersebut menjadi tipe data integer agar dapat digunakan dalam operasi matematika.
# 2. Operator penjumlahan digunakan untuk menjumlahkan nilai dari kedua angka.
# 3. Operator pengurangan digunakan untuk menghitung selisih antara angka pertama dan angka kedua.
# 4. Operator perkalian digunakan untuk mengalikan kedua angka.
# 5. Operator pembagian digunakan untuk membagi angka pertama dengan angka kedua dan menghasilkan nilai yang dapat berupa bilangan desimal.
# 6. Operator pembagian bulat digunakan untuk mendapatkan hasil pembagian dalam bentuk bilangan bulat.
# 7. Operator sisa bagi digunakan untuk mendapatkan sisa dari hasil pembagian kedua angka.
# 8. Operator perpangkatan digunakan untuk menghitung angka pertama yang dipangkatkan dengan angka kedua.
# 9. Percabangan digunakan untuk memastikan angka yang menjadi pembagi tidak bernilai nol sehingga pembagian dapat dilakukan dengan benar.

# %% [markdown]
# ### 2.2.2 Program "Assignment_2511533027"

# %%
angka1_3027 = int(input("Input angka-1: "))
angka2_3027 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_3027)
print("Nilai angka2 =", angka2_3027)

#Assignment biasa
hasil = angka1_3027
print("\nAssignment Biasa (=)")
print("Hasil =", hasil)

#Assignment penambahan
hasil = angka1_3027
hasil += angka2_3027
print("\nAssignment Penambahan (+=)")
print("Hasil =", hasil)

#Assignment pengurangan
hasil = angka1_3027
hasil -= angka2_3027
print("\nAssignment Pengurangan (-=)")
print("Hasil =", hasil)

#Assignment perkalian
hasil = angka1_3027
hasil *= angka2_3027
print("\nAssignment Perkalian (*=)")
print("Hasil =", hasil)

#Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3027 != 0:
    hasil = angka1_3027
    hasil /= angka2_3027
    print("\nAssignment Pembagian (/=)")
    print("Hasil =", hasil)
    
    #Operator tambahan
    hasil = angka1_3027
    hasil //= angka2_3027
    print("\nAssignment Pembagian Bulat (//=)")
    print("Hasil =", hasil)
    
    hasil = angka1_3027
    hasil %= angka2_3027
    print("\nAssignment Sisa Bagi (%=)")
    print("Hasil =", hasil)
    
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")
    
#Operator tambahan: assignment perpangkatan
hasil = angka1_3027
hasil **= angka2_3027
print("\nAssignment Perpangkatan (**=)")
print("Hasil =", hasil)

# %% [markdown]
# **Penjelasan:** Kode kedua digunakan untuk mempelajari operator assignment yang berfungsi memberikan dan memperbarui nilai suatu variabel.
#
# 1. Program meminta pengguna memasukkan dua angka dan mengubahnya menjadi tipe data integer.
# 2. Assignment biasa digunakan untuk memberikan nilai dari suatu variabel ke variabel lainnya.
# 3. Operator += digunakan untuk menambahkan suatu nilai ke nilai yang sudah tersimpan dalam variabel.
# 4. Operator -= digunakan untuk mengurangi nilai variabel dengan nilai tertentu.
# 5. Operator *= digunakan untuk mengalikan nilai variabel dengan nilai tertentu.
# 6. Operator /= digunakan untuk membagi nilai variabel dan menyimpan hasil pembagian tersebut ke variabel.
# 7. Operator //= digunakan untuk melakukan pembagian bulat sekaligus memperbarui nilai variabel.
# 8. Operator %= digunakan untuk mencari sisa bagi sekaligus menyimpan hasilnya ke variabel.
# 9. Operator **= digunakan untuk melakukan perpangkatan sekaligus memperbarui nilai variabel.

# %% [markdown]
# ### 2.2.3 Program "Bitwise_2511533027"

# %%
print("\n================================")
print("3. OPERATOR BITWISE")
print("================================")

angka1_3027 = int(input("Masukkan angka bitwise-1: "))
angka2_3027 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan binner")
print("angka1 =", angka1_3027, "| biner =", bin(angka1_3027))
print("angka2 =", angka2_3027, "| biner =", bin(angka2_3027))

#Bitwise AND
hasil = angka1_3027 & angka2_3027
print("\nBitwise AND (&)")
print(angka1_3027, "&", angka2_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))

#Bitwise OR
hasil = angka1_3027 | angka2_3027
print("\nBitwise OR (|)")
print(angka1_3027, "|", angka2_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))

#Bitwise XOR
hasil = angka1_3027 ^ angka2_3027
print("\nBitwise XOR (^)")
print(angka1_3027, "^", angka2_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))

#Bitwise NOT
hasil = ~angka1_3027
print("\nBitwise NOT (~)")
print("~", angka1_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))


#Bitwise geser kiri
jumlah_geser_3027 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil = angka1_3027 << jumlah_geser_3027
print("\nBitwise Geser Kiri (<<)")
print(angka1_3027, "<<", jumlah_geser_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))

#Bitwise geser kanan
hasil = angka1_3027 >> jumlah_geser_3027
print("\nBitwise Geser Kanan (>>)")
print(angka1_3027, ">>", jumlah_geser_3027, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit) =", format(hasil, "08b"))

# %% [markdown]
# **Penjelasan:** Kode ketiga digunakan untuk mempelajari operasi bitwise pada bilangan berdasarkan representasi binernya.
#
# 1. Program meminta pengguna memasukkan dua bilangan integer yang akan digunakan dalam operasi bitwise.
# 2. Fungsi bin() digunakan untuk menampilkan bilangan desimal ke dalam bentuk biner.
# 3. Operator AND digunakan untuk membandingkan setiap bit dan menghasilkan nilai 1 apabila kedua bit sama-sama bernilai 1.
# 4. Operator OR digunakan untuk membandingkan setiap bit dan menghasilkan nilai 1 apabila salah satu atau kedua bit bernilai 1.
# 5. Operator XOR digunakan untuk membandingkan setiap bit dan menghasilkan nilai 1 apabila kedua bit memiliki nilai yang berbeda.
# 6. Operator NOT digunakan untuk membalik nilai bit dari suatu bilangan.
# 7. Operator geser kiri digunakan untuk menggeser posisi bit ke sebelah kiri sesuai jumlah pergeseran yang diberikan.
# 8. Operator geser kanan digunakan untuk menggeser posisi bit ke sebelah kanan sesuai jumlah pergeseran yang diberikan.
# 9. Fungsi format() digunakan untuk menampilkan hasil operasi dalam bentuk biner dengan panjang 8 bit.

# %% [markdown]
# ### 2.2.4 Program "Lainnya_2511533027"

# %%
print("================================")
print("1. OPERATOR KEANGGOTAAN")
print("================================")

#Input beberapa data yang dipisahkan dengan koma
input_data_3027 = input("Input beberapa angka, pisahkan dengan koma: ")

#Mengubah input menjadi list integer
data_3027 = [int(angka.strip()) for angka in input_data_3027.split(",")]

nilai_dicari_3027 = int(input("Masukkan angka yang ingin dicari: "))

#Operator in
hasil = nilai_dicari_3027 in data_3027
print("\nOperator Keanggotaan IN")
print(nilai_dicari_3027, "in", data_3027, "=", hasil)

#Operator not in
hasil = nilai_dicari_3027 not in data_3027
print("\nOperator Keanggotaan NOT IN")
print(nilai_dicari_3027, "not in", data_3027, "=", hasil)

print("\n================================")
print("2. OPERATOR IDENTITAS")
print("================================")

#Objek1 menggunakan list dari input pengguna
objek1_3027 = data_3027

#Objek2 merujuk pada objek yang sama dengan objek1
objek2_3027 = objek1_3027

#Objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_3027 = data_3027.copy()

print("objek1 =", objek1_3027)
print("objek2 =", objek2_3027)
print("objek3 =", objek3_3027)

#Operator is
hasil = objek1_3027 is objek2_3027
print("\nOperator Identitas IS")
print("objek1 is objek2 =", hasil)

#Operator is not
hasil = objek1_3027 is not objek3_3027
print("\nOperator Identitas IS NOT")
print("objek1 is not objek3 =", hasil)

#Membandingkan identitas dan nilai
print("\nPerbandingan Identitas dan Nilai")
print("objek1 is objek3 =", objek1_3027 is objek3_3027)
print("objek1 == objek3 =", objek1_3027 == objek3_3027)

# %% [markdown]
# **Penjelasan:** Kode keempat digunakan untuk mempelajari operator keanggotaan dan operator identitas.
#
# A. Operator Keanggotaan
# 1. Program meminta pengguna memasukkan beberapa angka yang dipisahkan dengan tanda koma.
# 2. Data yang dimasukkan kemudian diubah menjadi sebuah list berisi bilangan integer.
# 3. Program meminta pengguna memasukkan angka yang ingin dicari di dalam list.
# 4. Operator in digunakan untuk memeriksa apakah angka yang dicari terdapat di dalam list.
# 5. Operator not in digunakan untuk memeriksa apakah angka yang dicari tidak terdapat di dalam list.
# 6. Hasil dari kedua pemeriksaan tersebut berupa nilai Boolean, yaitu True atau False.
#
# B. Operator Identitas
# 1. Program membuat beberapa objek list untuk menunjukkan perbedaan antara objek yang sama dan objek yang memiliki isi sama.
# 2. Dua variabel dibuat agar merujuk pada objek list yang sama.
# 3. Objek lain dibuat menggunakan copy() sehingga memiliki isi yang sama, tetapi merupakan objek baru.
# 4. Operator is digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.
# 5. Operator is not digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang berbeda.
# 6. Perbandingan menggunakan is dan == menunjukkan bahwa is membandingkan identitas objek, sedangkan == membandingkan nilai atau isi objek.

# %% [markdown]
# ### 2.2.5 Program "Logika_2511533027"

# %%
a1_3027 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_3027 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_3027)
print("A2 =", a2_3027)

#Konjungsi, bernilai true jika keduanya true
hasil = a1_3027 and a2_3027
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil)

#Disjungsi bernilai true jika salah satunya true
hasil = a1_3027 or a2_3027
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil)

#Negasi A1: membalik niLai A2
hasil = not a1_3027
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil)

#Negasi A2: membalik Nilai A2
hasil = not a2_3027
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil)

#XOR: bernilai true jika kedua nilai berbeda
hasil = a1_3027 != a2_3027
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil)

# %% [markdown]
# **Penjelasan:** Kode kelima digunakan untuk mempelajari operator logika menggunakan nilai Boolean.
#
# 1. Program meminta pengguna memasukkan dua nilai Boolean berupa true atau false.
# 2. Input kemudian diubah menjadi huruf kecil dan dibandingkan dengan kata "true" sehingga menghasilkan nilai True atau False.
# 3. Operator and digunakan untuk menggabungkan dua kondisi dan menghasilkan True jika kedua kondisi bernilai True.
# 4. Operator or digunakan untuk menggabungkan dua kondisi dan menghasilkan True jika minimal salah satu kondisi bernilai True.
# 5. Operator not digunakan untuk membalik nilai Boolean dari suatu kondisi.
# 6. Konsep XOR diterapkan menggunakan operator !=, yang menghasilkan True apabila kedua nilai Boolean memiliki nilai yang berbeda.

# %% [markdown]
# ### 2.2.6 Program "Perbandingan_2511533027"

# %%
angka1_3027 = int(input("Input angka-1: "))
angka2_3027 = int(input("Input angka-2: "))

#Lebih besar dari
hasil = angka1_3027 > angka2_3027
print("\nOperator Lebih Besar Dari")
print("angka1_3027 > angka2_3027 =", hasil)

#Lebih kecil dari
hasil = angka1_3027 < angka2_3027
print("\nOperator Lebih Kecil Dari")
print("angka1_3027 < angka2_3027 =", hasil)

#Lebih besar dari atau sama dengan
hasil = angka1_3027 >= angka2_3027
print("\nOperator Lebih Besar Dari atau Sama Dengan")
print("angka1_3027 >= angka2_3027 =", hasil)

#Lebih kecil dari atau sama dengan
hasil = angka1_3027 <= angka2_3027
print("\nOperator Lebih Kecil Dari atau Sama Dengan")
print("angka1_3027 <= angka2_3027 =", hasil)

#Sama dengan
hasil = angka1_3027 == angka2_3027
print("\nOperator Sama Dengan")
print("angka1_3027 == angka2_3027 =", hasil)

#Tidak sama dengan
hasil = angka1_3027 != angka2_3027
print("\nOperator Tidak Sama Dengan")
print("angka1_3027 != angka2_3027 =", hasil)

#Tambahan: perbandingan berantai dalam python
hasil = 0 < angka1_3027 < 100
print("\nPerbandingan Berantai")
print("0 < angka1_3027 < 100 =", hasil)

hasil = 0 < angka2_3027 < 100
print("0 < angka2_3027 < 100 =", hasil)

# %% [markdown]
# **Penjelasan:** Kode keenam digunakan untuk mempelajari berbagai operator perbandingan pada Python.
#
# 1. Program meminta pengguna memasukkan dua angka dalam bentuk integer.
# 2. Operator > digunakan untuk memeriksa apakah angka pertama lebih besar dari angka kedua.
# 3. Operator < digunakan untuk memeriksa apakah angka pertama lebih kecil dari angka kedua.
# 4. Operator >= digunakan untuk memeriksa apakah angka pertama lebih besar atau sama dengan angka kedua.
# 5. Operator <= digunakan untuk memeriksa apakah angka pertama lebih kecil atau sama dengan angka kedua.
# 6. Operator == digunakan untuk memeriksa apakah kedua angka memiliki nilai yang sama.
# 7. Operator != digunakan untuk memeriksa apakah kedua angka memiliki nilai yang berbeda.
# 8. Perbandingan berantai digunakan untuk memeriksa apakah suatu nilai berada dalam rentang tertentu, yaitu lebih besar dari 0 dan lebih kecil dari 100.
# 9. Setiap hasil dari operator perbandingan berupa nilai Boolean, yaitu True jika kondisi terpenuhi dan False jika kondisi tidak terpenuhi.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/Soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2511533027"

# %%
print("========================================")
print("       SISTEM TRANSAKSI TOKO")
print("========================================")

# INPUT DATA PELANGGAN
nama_3027 = input("Masukkan Nama Pelanggan : ")
status_3027 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_3027 = int(input("Masukkan Total Belanja : Rp"))
jumlah_barang_3027 = int(input("Masukkan Jumlah Barang : "))
kode_promo_3027 = input("Masukkan Kode Promo : ").upper()

# DATA PROMO
daftar_promo_3027 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

# OPERATOR PERBANDINGAN
syarat_belanja_3027 = total_belanja_3027 >= 200000
syarat_barang_3027 = jumlah_barang_3027 >= 3
status_member_3027 = status_3027 == "member"

# OPERATOR KEANGGOTAAN
promo_tersedia_3027 = kode_promo_3027 in daftar_promo_3027
promo_tidak_tersedia_3027 = kode_promo_3027 not in daftar_promo_3027

# OPERATOR LOGIKA
diskon_member_3027 = status_member_3027 and syarat_belanja_3027

promo_3027 = syarat_barang_3027 and promo_tersedia_3027

hak_akses_3027 = (
    diskon_member_3027
    or promo_3027
)

bukan_member_3027 = not status_member_3027

# OPERATOR ARITMATIKA
diskon_3027 = 0

if diskon_member_3027:
    diskon_3027 = total_belanja_3027 * 10 / 100

total_pembayaran_3027 = total_belanja_3027 - diskon_3027

rata_rata_3027 = total_belanja_3027 / jumlah_barang_3027

sisa_bagi_3027 = total_belanja_3027 % jumlah_barang_3027

# OPERATOR PENUGASAN
poin_3027 = 0
poin_3027 += jumlah_barang_3027

if diskon_member_3027:
    poin_3027 += 10

total_pembayaran_3027 -= 0

# OPERATOR IDENTITY
objek_status_3027 = status_3027
status_sama_3027 = objek_status_3027 is status_3027
status_tidak_sama_3027 = objek_status_3027 is not status_3027

nilai_a_3027 = 100
nilai_b_3027 = 100
nilai_sama_3027 = nilai_a_3027 == nilai_b_3027

# OPERATOR BITWISE
kode_member_3027 = 1       # 0001
kode_belanja_3027 = 2      # 0010
kode_barang_3027 = 4       # 0100
kode_promo_bit_3027 = 8    # 1000

kode_status_3027 = 0

if status_member_3027:
    kode_status_3027 = kode_status_3027 | kode_member_3027

if syarat_belanja_3027:
    kode_status_3027 = kode_status_3027 | kode_belanja_3027

if syarat_barang_3027:
    kode_status_3027 = kode_status_3027 | kode_barang_3027

if promo_tersedia_3027:
    kode_status_3027 = kode_status_3027 | kode_promo_bit_3027


# AND (&)
cek_member_3027 = kode_status_3027 & kode_member_3027
cek_promo_3027 = kode_status_3027 & kode_promo_bit_3027

# XOR (^)
kode_referensi_3027 = 11
hasil_xor_3027 = kode_status_3027 ^ kode_referensi_3027

# SHIFT (<<)
hasil_shift_3027 = kode_status_3027 << 1

# HAK AKSES
member_access_3027 = cek_member_3027 == 1
promo_access_3027 = cek_promo_3027 == 8
free_shipping_access_3027 = promo_3027 and promo_tersedia_3027

# OUTPUT DATA
print("\n========================================")
print("           DATA PELANGGAN")
print("========================================")
print("Nama Pelanggan       :", nama_3027)
print("Status Pelanggan     :", status_3027)
print("Total Belanja        : Rp", total_belanja_3027)
print("Jumlah Barang        :", jumlah_barang_3027)
print("Kode Promo           :", kode_promo_3027)


print("\n========================================")
print("          HASIL VALIDASI")
print("========================================")
print("Belanja >= Rp200000  :", syarat_belanja_3027)
print("Jumlah Barang >= 3   :", syarat_barang_3027)
print("Status Member        :", status_member_3027)
print("Kode Promo Tersedia  :", promo_tersedia_3027)
print("Kode Promo Tidak Ada :", promo_tidak_tersedia_3027)
print("Mendapat Diskon      :", diskon_member_3027)
print("Mendapatkan Promo    :", promo_3027)


print("\n========================================")
print("          HASIL PERHITUNGAN")
print("========================================")
print("Besarnya Diskon      : Rp", int(diskon_3027))
print("Total Pembayaran     : Rp", int(total_pembayaran_3027))
print("Rata-rata Harga      : Rp", int(rata_rata_3027))
print("Sisa Pembagian       :", sisa_bagi_3027)
print("Jumlah Poin          :", poin_3027)


print("\n========================================")
print("        HAK AKSES PELANGGAN")
print("========================================")
print("Kode Hak Akses       :", format(kode_status_3027, "04b"))
print("Member Access        :", member_access_3027)
print("Promo Access         :", promo_access_3027)
print("Free Shipping Access :", free_shipping_access_3027)


print("\n========================================")
print("          HASIL OPERATOR")
print("========================================")

print("\n--- OPERATOR ARITMATIKA ---")
print("Diskon = Total Belanja * 10 / 100")
print("Total Pembayaran = Total Belanja - Diskon")
print("Rata-rata = Total Belanja / Jumlah Barang")
print("Sisa = Total Belanja % Jumlah Barang")

print("\n--- OPERATOR PERBANDINGAN ---")
print("Total Belanja >= 200000 :", syarat_belanja_3027)
print("Jumlah Barang >= 3      :", syarat_barang_3027)
print("Status == member        :", status_member_3027)

print("\n--- OPERATOR LOGIKA ---")
print("Member AND Belanja      :", diskon_member_3027)
print("Barang AND Promo        :", promo_3027)
print("Diskon OR Promo         :", hak_akses_3027)
print("NOT Member              :", bukan_member_3027)

print("\n--- OPERATOR PENUGASAN ---")
print("Poin += Jumlah Barang   :", poin_3027)
print("Pembayaran -= 0         :", int(total_pembayaran_3027))

print("\n--- OPERATOR KEANGGOTAAN ---")
print("Kode Promo IN daftar    :", promo_tersedia_3027)
print("Kode Promo NOT IN daftar:", promo_tidak_tersedia_3027)

print("\n--- OPERATOR IDENTITAS ---")
print("Objek status IS status  :", status_sama_3027)
print("Objek status IS NOT    :", status_tidak_sama_3027)
print("100 == 100             :", nilai_sama_3027)

print("\n--- OPERATOR BITWISE ---")
print("Kode Status             :", format(kode_status_3027, "04b"))
print("Kode Desimal            :", kode_status_3027)

print("\nCek Member:")
print(format(kode_status_3027, "04b"), "&", format(kode_member_3027, "04b"))
print("Hasil Biner             :", format(cek_member_3027, "04b"))
print("Hasil Desimal           :", cek_member_3027)

print("\nCek Promo:")
print(format(kode_status_3027, "04b"), "&", format(kode_promo_bit_3027, "04b"))
print("Hasil Biner             :", format(cek_promo_3027, "04b"))
print("Hasil Desimal           :", cek_promo_3027)

print("\nPerbandingan Status:")
print("Kode Transaksi          :", format(kode_status_3027, "04b"))
print("Kode Referensi          :", format(kode_referensi_3027, "04b"))
print(format(kode_status_3027, "04b"), "^", format(kode_referensi_3027, "04b"))
print("Hasil Biner             :", format(hasil_xor_3027, "04b"))
print("Hasil Desimal           :", hasil_xor_3027)

print("\nShift:")
print(format(kode_status_3027, "04b"), "<< 1")
print("Hasil Biner             :", format(hasil_shift_3027, "b"))
print("Hasil Desimal           :", hasil_shift_3027)

print("\n========================================")
print("              SELESAI")
print("========================================")
# Out:
# ...
#        SISTEM TRANSAKSI TOKO
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       4
#       5 # INPUT DATA PELANGGAN
#       6 nama_3027 = input("Masukkan Nama Pelanggan : ")
#       7 status_3027 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
# ----> 8 total_belanja_3027 = int(input("Masukkan Total Belanja : Rp"))
#       9 jumlah_barang_3027 = int(input("Masukkan Jumlah Barang : "))
#      10 kode_promo_3027 = input("Masukkan Kode Promo : ").upper()
#      11
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# **Penjelasan Kode:**
# Alur logika program Sistem Transaksi Toko adalah sebagai berikut:
#
# 1. Input Data
# Program meminta nama, status pelanggan, total belanja, jumlah barang, dan kode promo.
# 2. Validasi Data
# Program mengecek apakah pelanggan merupakan member, belanja minimal Rp200.000, jumlah barang minimal 3, dan kode promo tersedia.
# Hasil pengecekan berupa True atau False.
# 3. Operator Logika
# Kondisi member dan belanja digabungkan menggunakan and untuk menentukan diskon.
# Kondisi jumlah barang dan promo digabungkan untuk menentukan promo.
# Operator or menentukan hak akses jika salah satu syarat terpenuhi.
# Operator not digunakan untuk mengetahui apakah pelanggan bukan member.
# 4. Perhitungan Transaksi
# Jika memenuhi syarat, pelanggan mendapat diskon 10%.
# Program menghitung total pembayaran, rata-rata harga barang, dan sisa pembagian menggunakan operator aritmatika.
# 5. Perhitungan Poin
# Poin awal ditambah berdasarkan jumlah barang menggunakan operator +=.
# Jika mendapat diskon member, pelanggan memperoleh tambahan 10 poin.
# 6. Operator Identitas
# Operator is dan is not digunakan untuk mengecek apakah dua variabel merujuk pada objek yang sama.
# Berbeda dengan == yang membandingkan nilai.
# 7. Operator Bitwise
# Setiap kondisi diberi kode bit, yaitu member 0001, belanja 0010, barang 0100, dan promo 1000.
# Operator | digunakan untuk membentuk kode status berdasarkan kondisi yang terpenuhi.
# Operator & digunakan untuk mengecek status tertentu, sedangkan ^ digunakan untuk membandingkan perbedaan bit.
# Operator << digunakan untuk menggeser bit ke kiri.
# 8. Penentuan Hak Akses
# Hasil pengecekan bitwise digunakan untuk menentukan akses member, promo, dan free shipping.

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/Tugas 1.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# <div align="center">
# <img src="images/Tugas 2.png" width="400"><br>
# <em>Gambar 2.4 : Output Tugas Praktikum</em>
# </div>
#
# <div align="center">
# <img src="images/Tugas 3.png" width="400"><br>
# <em>Gambar 2.5 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
# 1. Data Pelanggan
# Menampilkan kembali data yang dimasukkan, yaitu nama, status, total belanja, jumlah barang, dan kode promo.
# 2. Hasil Validasi
# Menampilkan hasil pengecekan setiap syarat dalam bentuk True atau False, seperti syarat belanja, jumlah barang, status member, dan ketersediaan promo.
# 3. Hasil Perhitungan
# Menampilkan besarnya diskon, total pembayaran setelah diskon, rata-rata harga barang, sisa pembagian, dan jumlah poin pelanggan.
# 4. Hak Akses Pelanggan
# Menampilkan kode hak akses dalam bentuk biner serta status akses member, promo, dan free shipping.
# 5. Hasil Operator
# Menampilkan penerapan operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, dan bitwise beserta hasilnya.
# 6. Selesai
# Bagian akhir menunjukkan bahwa seluruh proses transaksi dan validasi telah selesai dijalankan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python memiliki berbagai jenis operator yang dapat digunakan untuk mengolah data dan membuat suatu program berjalan sesuai kondisi yang ditentukan. Operator yang dipelajari meliputi operator aritmatika, assignment, bitwise, keanggotaan, identitas, logika, dan perbandingan.
#
# Melalui beberapa kode program, dapat dipahami bahwa setiap operator memiliki fungsi yang berbeda, tetapi dapat digunakan secara bersama-sama dalam satu program. Hal tersebut diterapkan pada program Sistem Transaksi Toko, mulai dari menerima input pelanggan, melakukan validasi, menghitung diskon dan pembayaran, menentukan poin, hingga menentukan hak akses pelanggan.
#
# Dengan praktikum ini, pemahaman mengenai penggunaan operator Python serta penerapan kondisi True dan False menjadi lebih baik. Praktikum juga membantu memahami bagaimana berbagai operator dapat digabungkan untuk menyelesaikan suatu permasalahan dalam program secara terstruktur.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Microsoft, "Python in Visual Studio Code," Visual Studio Code Documentation, 2024. [Online]. Available: https://code.visualstudio.com/docs/python/python-tutorial
#
# [2] R. F. Septian, "E-Book Belajar Pemrograman Python Dasar," Repository UNIKOM, 2013. [Online]. Available: https://repository.unikom.ac.id/65984/
